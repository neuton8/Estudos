# %%
import scipy.stats as stats
import pandas as pd
import seaborn as sns
import numpy as np
import pylustrator
import matplotlib.pyplot as plt
pylustrator.start()
dados = pd.read_csv('tmdb_5000_movies.csv')

# %%
ax = sns.displot(data=dados, x='vote_average', kde=False, color='green',stat="density",bins=round(np.sqrt(len(dados))))
ax.set(xlabel='Nota média', ylabel='Densidade')
sns.set_style('white')
