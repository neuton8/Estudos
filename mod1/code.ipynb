# %%
import pandas as pd

films = pd.read_csv('ml-latest-small/ratings.csv')

# %%
films['rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.boxplot(films['rating'], orient='h')
# Out:
# <Axes: xlabel='rating'>
